# %%
#DNN not found
# !pip install tensorflow==2.7.0 tf-models-official==2.7.0 tensorflow_io==0.23.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 665.5 MB 22 kB/s
# ...
#      |████████████████████████████████| 1.8 MB 33.3 MB/s
# ...
#      |████████████████████████████████| 23.1 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 463 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 33.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 53.7 MB/s
# ...
#      |████████████████████████████████| 4.6 MB 68.7 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 352 kB 67.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 54.0 MB/s
# ...
#      |████████████████████████████████| 92 kB 13.0 MB/s
# ...
#      |████████████████████████████████| 48.3 MB 82 kB/s
# ...
#      |████████████████████████████████| 237 kB 79.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 58.5 MB/s
# ...
#      |████████████████████████████████| 99 kB 11.8 MB/s
# ...

# %%
# !git clone https://github.com/ttknguyen/FinalProject_CS232.git
# %cd FinalProject_CS232/
# !gdown -- 1AwgPLvIY3pHN24pqlC1-UMiBTwsJW7Ey
# !unzip model.zip
# Out:
# Cloning into 'FinalProject_CS232'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 30 (delta 4), reused 22 (delta 2), pack-reused 0
# Unpacking objects: 100% (30/30), done.
# /content/FinalProject_CS232
# Downloading...
# From: https://drive.google.com/uc?id=1AwgPLvIY3pHN24pqlC1-UMiBTwsJW7Ey
# To: /content/FinalProject_CS232/model.zip
# 100% 264M/264M [00:00<00:00, 268MB/s]

# %%
# !gdown --id 1_RvjDTJr4uEgbCmwHjzcys35swyI39PC
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1_RvjDTJr4uEgbCmwHjzcys35swyI39PC
# To: /content/FinalProject_CS232/VIVOSSPK01_R001.wav
# 100% 96.0k/96.0k [00:00<00:00, 84.5MB/s]

# %%
# %cd FinalProject_CS232/

# %%
from api_speech2text import speech2text, loadmodel
import tensorflow as tf
model = loadmodel('./model')
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-4.__call__
# ...

# %%
print(model)

# %%
from api_speech2text import speech2text, loadmodel
result = speech2text(model, './VIVOSSPK01_R001.wav')
result_lib = speech2text(model, './VIVOSSPK01_R001.wav', 'ASR_lib')

# %%
result, result_lib
# Out:
# ('khápxảo', 'khách sạn')
